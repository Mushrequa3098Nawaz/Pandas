# %%
import numpy as np
import pandas as pd
import io
#from google.colab import files

# %%
#uploaded = files.upload()
df = pd.read_csv(r"C:\Users\nawaz\Downloads\matches.csv")
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.head(3)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %%
# Q1. Find the total number of matches played till now in IPL
#since the number of rows is the number of matches played
a=len(df)
print("total number of matches played:",a)
# Out:
# total number of matches played: 636

# %%
# Q2. Create a new dataframe from df which will have all the alternate rows and columns from df starting from 0
print(df.shape) #number of rows and coloumns 
df.iloc[1:636:2,1:18:2]
# Out:
# (636, 18)
#      season        date                        team2 toss_decision  \
# 1      2017  2017-04-06       Rising Pune Supergiant         field
# 3      2017  2017-04-08              Kings XI Punjab         field
# 5      2017  2017-04-09          Sunrisers Hyderabad         field
# 7      2017  2017-04-10              Kings XI Punjab           bat
# 9      2017  2017-04-12               Mumbai Indians         field
# ..      ...         ...                          ...           ...
# 627    2016  2016-05-20             Delhi Daredevils         field
# 629    2016  2016-05-21                Gujarat Lions         field
# 631    2016  2016-05-22  Royal Challengers Bangalore         field
# 633    2016  2016-05-25        Kolkata Knight Riders         field
# 635    2016  2016-05-29  Royal Challengers Bangalore           bat
#
#      dl_applied  win_by_runs player_of_match          umpire1  umpire3
# 1             0            0       SPD Smith   A Nand Kishore      NaN
# ...

# %%
# Q3. Find the number of matches played in Mumbai in the period of 2013 and 2017
mask1=df['city']=='Mumbai' 
mask2= ((df["season"]<=2017)&(df["season"]>=2013))
print("number of matches played in mumbai between 2017 and 2013: ",len(df[mask1 &mask2]))
# Out:
# number of matches played in mumbai between 2017 and 2013:  38

# %%
# Q4. Find the number of matches where the margin of victory was greater than 30
x=df[df["win_by_runs"]>30]
print("number of matches where the margin is greater than 30: ",len(x))
# Out:
# number of matches where the margin is greater than 30:  103

# %%
# Q5. What percent times KKR decides to bat after winning the toss

# %%
m=len(df[(df["toss_winner"]=="Kolkata Knight Riders") & (df["toss_decision"]=="bat")])
n=len(df[df["toss_winner"]=="Kolkata Knight Riders"])
y=m/n*100
print("KKR chose to bat ",y,"% times after winning the toss")
# Out:
# KKR chose to bat  38.46153846153847 % times after winning the toss
